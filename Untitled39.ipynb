# %%
import pandas as pd
from statsforecast import StatsForecast
from statsforecast.models import Naive
import matplotlib.pyplot as plt
import statsforecast as sf
from utilsforecast.plotting import plot_series
import numpy as np
from sktime.forecasting.ets import AutoETS
from sktime.forecasting.base import ForecastingHorizon
from sklearn.metrics import mean_absolute_percentage_error
from sktime.forecasting.arima import AutoARIMA
from sktime.forecasting.fbprophet import Prophet

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_excel('Downloads/CMO-Historical-Data-Monthly.xlsx', sheet_name='Monthly Prices')
df_clean = df.drop([0, 1, 2, 3, 4]) 
new_columns = df.iloc[3, 1:].tolist()  
df_clean.columns = ['Month'] + new_columns  
df_clean['Month'] = pd.to_datetime(df_clean['Month'], format='%YM%m')
df_clean.set_index('Month', inplace=True)
df_clean = df_clean.sort_index()
df_clean = df_clean.dropna(axis=1, how='all')

df = df_clean
df.index = df.index.to_period('M')
for col in df.columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')
df
# Out:
#          Crude oil, average  Crude oil, Brent  Crude oil, Dubai  \
# Month
# 1960-01            1.630000             1.630              1.63
# 1960-02            1.630000             1.630              1.63
# 1960-03            1.630000             1.630              1.63
# 1960-04            1.630000             1.630              1.63
# 1960-05            1.630000             1.630              1.63
# ...                     ...               ...               ...
# 2024-11           72.291667            74.395             72.79
# 2024-12           72.311000            73.833             73.31
# 2025-01           78.162000            79.206             80.14
# 2025-02           73.819000            75.157             74.97
# 2025-03           70.701333            72.574             71.71
#
#          Crude oil, WTI  Coal, Australian  Coal, South African **  \
# Month
# 1960-01             NaN               NaN                     NaN
# 1960-02             NaN               NaN                     NaN
# 1960-03             NaN               NaN                     NaN
# 1960-04             NaN               NaN                     NaN
# 1960-05             NaN               NaN                     NaN
# ...                 ...               ...                     ...
# 2024-11           69.69            142.12                  106.82
# 2024-12           69.79            129.81                  105.47
# 2025-01           75.14            118.60                  103.28
# 2025-02           71.33            106.93                  100.41
# 2025-03           67.82            103.97                   97.99
#
#          Natural gas, US  Natural gas, Europe  Liquefied natural gas, Japan  \
# Month
# 1960-01           0.1400             0.404774                           NaN
# 1960-02           0.1400             0.404774                           NaN
# 1960-03           0.1400             0.404774                           NaN
# 1960-04           0.1400             0.404774                           NaN
# 1960-05           0.1400             0.404774                           NaN
# ...                  ...                  ...                           ...
# 2024-11           2.1045            13.926400                     12.822731
# 2024-12           3.0229            13.856621                     12.640616
# 2025-01           4.0991            14.663512                     13.193106
# 2025-02           4.2226            15.340532                     12.781781
# 2025-03           4.1281            13.235407                     12.700000
#
#          Natural gas index  ...     Aluminum  Iron ore, cfr spot   Copper  \
# Month                       ...
# 1960-01                NaN  ...   511.471832               11.42   715.40
# 1960-02                NaN  ...   511.471832               11.42   728.19
# 1960-03                NaN  ...   511.471832               11.42   684.94
# 1960-04                NaN  ...   511.471832               11.42   723.11
# 1960-05                NaN  ...   511.471832               11.42   684.75
# ...                    ...  ...          ...                 ...      ...
# 2024-11         100.448776  ...  2582.190000              100.50  9075.73
# 2024-12         111.146139  ...  2541.020000              102.21  8916.32
# 2025-01         128.425081  ...  2573.400000               99.58  8991.41
# 2025-02         132.864654  ...  2657.600000              105.08  9330.60
# 2025-03         121.653992  ...  2658.290000              100.10  9739.68
#
#             Lead       Tin    Nickel     Zinc     Gold  Platinum   Silver
# Month
# 1960-01   206.10   2180.40   1631.00   260.80    35.27     83.50   0.9137
# 1960-02   203.70   2180.40   1631.00   244.90    35.27     83.50   0.9137
# 1960-03   210.30   2173.80   1631.00   248.70    35.27     83.50   0.9137
# 1960-04   213.60   2178.20   1631.00   254.60    35.27     83.50   0.9137
# 1960-05   213.40   2162.70   1631.00   253.80    35.27     83.50   0.9137
# ...          ...       ...       ...      ...      ...       ...      ...
# 2024-11  1987.53  29654.89  15723.06  3004.20  2651.13    965.53  31.0940
# 2024-12  1990.43  28864.99  15444.89  3034.16  2648.01    937.88  30.7640
# 2025-01  1921.36  29612.36  15394.14  2818.96  2709.69    949.23  30.4110
# 2025-02  1956.55  31832.96  15288.09  2800.14  2894.73    978.25  32.1520
# 2025-03  2033.21  34047.87  16065.69  2889.29  2983.25    980.05  33.1880
#
# [783 rows x 71 columns]

# %%
def get_mape(ts_num, forecaster):
    test_start = '2024-01'
    test_end = '2024-12'
    series = df.iloc[:, ts_num].dropna()
    train = series[series.index < test_start]
    test = series[(series.index >= test_start) & (series.index <= test_end)]
    forecaster.fit(train)
    fh = ForecastingHorizon(test.index, is_relative=False)
    y_pred = forecaster.predict(fh)
    return mean_absolute_percentage_error(test, y_pred)

# %%
ARIMA = AutoARIMA(
    sp=12,
    seasonal=False,
    stepwise=False,       
    n_jobs=-1,            
    trace=False,
    error_action='ignore',
    suppress_warnings=True
)

SARIMA = AutoARIMA(
    sp=12,
    seasonal=True,
    stepwise=False,      
    n_jobs=-1,          
    trace=False,
    error_action='ignore',
    suppress_warnings=True
)

ETS = AutoETS(auto=True, sp=12, n_jobs=-1)

# %%
results = []
models = [('ETS', ETS), ('ARIMA', ARIMA), ('SARIMA', SARIMA)]
for i in range(len(df.columns)):
    verdicts = {}
    try:
        for model in models:
            verdicts[model[0]] = get_mape(i, model[1])
    except:
        pass
    results.append(verdicts)
    print(i)
    print(verdicts)
# Out:
# 0
# {'ETS': 0.05041594454150172, 'ARIMA': 0.0771481043446248, 'SARIMA': 0.10215867907136476}
# 1
# {'ETS': 0.05063381582071396, 'ARIMA': 0.07430411363761352, 'SARIMA': 0.1008265262310803}
# 2
# {'ETS': 0.05651802525515215, 'ARIMA': 0.07249933292832034, 'SARIMA': 0.07249933292832034}
# 3
# {'ETS': 0.0667070345126737, 'ARIMA': 0.07871980913916876, 'SARIMA': 0.10407495814893235}
# 4
# {'ETS': 0.058890930939923286, 'ARIMA': 0.04360372163649562, 'SARIMA': 0.04360372163649562}
# 5
# {'ETS': 0.013723103707384969, 'ARIMA': 0.0367207759091655, 'SARIMA': 0.0367207759091655}
# 6
# {'ETS': 0.27083776538282783, 'ARIMA': 0.2655210512784956, 'SARIMA': 0.2655210512784956}
# 7
# {'ETS': 0.16014121900298572, 'ARIMA': 0.21845047754877375, 'SARIMA': 0.21845047754877375}
# 8
# {'ETS': 0.23599533206025414, 'ARIMA': 0.20345532774304068, 'SARIMA': 0.20345532774304068}
# 9
# {'ETS': 0.1383881648304073, 'ARIMA': 0.22707140800133338, 'SARIMA': 0.22707140800133338}
# 10
# {'ETS': 0.3911542664354668, 'ARIMA': 0.3873447962845413, 'SARIMA': 0.3873447962845413}
# 11
# {'ETS': 0.12133081820798229, 'ARIMA': 0.1622955084781457, 'SARIMA': 0.1622955084781457}
# 12
# {'ETS': 0.25045473705952814, 'ARIMA': 0.2676047680135209, 'SARIMA': 0.2676047680135209}
# 13
# {'ETS': 0.09109829867085051, 'ARIMA': 0.11304890651575622, 'SARIMA': 0.10602962093753121}
# 14
# {'ETS': 0.0915128559542101, 'ARIMA': 0.10573575039132599, 'SARIMA': 0.11308765180703136}
# 15
# {'ETS': 0.13621479079377022, 'ARIMA': 0.2537554587654837, 'SARIMA': 0.16300893697144694}
# 16
# {'ETS': 0.04197162991429961, 'ARIMA': 0.02941508653354112, 'SARIMA': 0.03610654365755913}
# 17
# {'ETS': 0.23711459225203804, 'ARIMA': 0.2533754864593652, 'SARIMA': 0.2533754864593652}
# 18
# {'ETS': 0.18363135165787248, 'ARIMA': 0.1836269896335144, 'SARIMA': 0.17183661095577882}
# 19
# {'ETS': 0.07620143701714326, 'ARIMA': 0.07977787284249901, 'SARIMA': 0.07977787284249901}
# 20
# {'ETS': 0.08372115411807513, 'ARIMA': 0.08961944944896572, 'SARIMA': 0.08961944944896572}
# 21
# {'ETS': 0.15783585070196252, 'ARIMA': 0.14752704070807324, 'SARIMA': 0.14752704070807324}
# 22
# {'ETS': 0.3062320153382457, 'ARIMA': 0.2685873958089522, 'SARIMA': 0.2685873958089522}
# 23
# {'ETS': 0.16461653452802963, 'ARIMA': 0.21038103947620215, 'SARIMA': 0.18590342139227026}
# 24
# {'ETS': 0.06285471570228655, 'ARIMA': 0.05327037683093441, 'SARIMA': 0.05327037683093441}
# 25
# {'ETS': 0.17988857323549035, 'ARIMA': 0.12731457140407712, 'SARIMA': 0.12731457140407712}
# 26
# {'ETS': 0.1052955924364637, 'ARIMA': 0.08597991200070094, 'SARIMA': 0.06916247445735825}
# 27
# {'ETS': 0.09706785771740385, 'ARIMA': 0.16486945019571345, 'SARIMA': 0.16486945019571345}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 6
#       4 verdicts = {}
#       5 for model in models:
# ----> 6     verdicts[model[0]] = get_mape(i, model[1])
#       7 results.append(verdicts)
#       8 print(i)
#
# Cell In[38], line 9, in get_mape(ts_num, forecaster)
#       7 forecaster.fit(train)
#       8 fh = ForecastingHorizon(test.index, is_relative=False)
# ----> 9 y_pred = forecaster.predict(fh)
#      10 return mean_absolute_percentage_error(test, y_pred)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sktime/forecasting/base/_base.py:454, in BaseForecaster.predict(self, fh, X)
#     451 X_inner = self._check_X(X=X)
#     453 # check fh and coerce to ForecastingHorizon, if not already passed in fit
# --> 454 fh = self._check_fh(fh)
#     456 # we call the ordinary _predict if no looping/vectorization needed
#     457 if not self._is_vectorized:
#
# File /opt/anaconda3/lib/python3.12/site-packages/sktime/forecasting/base/_base.py:1959, in BaseForecaster._check_fh(self, fh, pred_int)
#    1957     fh = check_fh(fh=fh)
#    1958 else:
# -> 1959     fh = check_fh(fh=fh, freq=self._cutoff)
#    1961 # fh is written to self if one of the following is true
#    1962 # - estimator has not been fitted yet (for safety from side effects)
#    1963 # - fh has not been seen yet
#    1964 # - fh has been seen, but was optional in fit,
#    1965 #     this means fh needs not be same and can be overwritten
#    1966 if not requires_fh or not self._fh or not self._is_fitted:
#
# File /opt/anaconda3/lib/python3.12/site-packages/sktime/utils/validation/forecasting.py:299, in check_fh(fh, enforce_relative, freq)
#     294 # Check if non-empty, note we check for empty values here, rather than
#     295 # during construction of ForecastingHorizon because ForecastingHorizon
#     296 # can be empty in some cases, but users should not create forecasting horizons
#     297 # with no values
#     298 if len(fh) == 0:
# --> 299     raise ValueError("`fh` must not be empty")
#     301 if enforce_relative and not fh.is_relative:
#     302     raise ValueError("`fh` must be relative, but found absolute `fh`")
#
# ValueError: `fh` must not be empty

# %%
for i in range(len(results), len(df.columns)):
    verdicts = {}
    try:
        for model in models:
            verdicts[model[0]] = get_mape(i, model[1])
    except:
        pass
    results.append(verdicts)
    print(i)
    print(verdicts)
# Out:
# 28
# {}
# 29
# {'ETS': 0.06358203341904645, 'ARIMA': 0.08884198140696788, 'SARIMA': 0.08884198140696788}
# 30
# {}
# 31
# {'ETS': 0.17215894497159331, 'ARIMA': 0.13210555315700256, 'SARIMA': 0.13210555315700256}
# 32
# {'ETS': 0.14214324196431935, 'ARIMA': 0.11501559303355352, 'SARIMA': 0.11501559303355352}
# 33
# {'ETS': 0.2459436944904859, 'ARIMA': 0.06781327835509732, 'SARIMA': 0.06781327835509732}
# 34
# {'ETS': 0.14034498893272282, 'ARIMA': 0.047531099057725894, 'SARIMA': 0.047531099057725894}
# 35
# {'ETS': 0.12042490797005619, 'ARIMA': 0.10468984063284692, 'SARIMA': 0.13677464548464288}
# 36
# {'ETS': 0.03219773652068573, 'ARIMA': 0.08609788730938174, 'SARIMA': 0.08609788730938174}
# 37
# {'ETS': 0.06447061378378922, 'ARIMA': 0.0208198717817173, 'SARIMA': 0.05155626608077709}
# 38
# {'ETS': 0.437133999207306, 'ARIMA': 0.37530807969848023, 'SARIMA': 0.4019715332364577}
# 39
# {'ETS': 0.10491742226115701, 'ARIMA': 0.1511294443501606, 'SARIMA': 0.1826642762243247}
# 40
# {'ETS': 0.17782568635645804, 'ARIMA': 0.1853680203319068, 'SARIMA': 0.1853680203319068}
# 41
# {'ETS': 0.1430765551600713, 'ARIMA': 0.11279146005061431, 'SARIMA': 0.11479519042420737}
# 42
# {'ETS': 0.04758539289306283, 'ARIMA': 0.043411467287074616, 'SARIMA': 0.043411467287074616}
# 43
# {}
# 44
# {'ETS': 0.02414899404025268, 'ARIMA': 0.016433903444262012, 'SARIMA': 0.016433903444262012}
# 45
# {'ETS': 0.03394348123524143, 'ARIMA': 0.04375167516033385, 'SARIMA': 0.04375167516033385}
# 46
# {'ETS': 0.04462979932680669, 'ARIMA': 0.048073581252690574, 'SARIMA': 0.048073581252690574}
# 47
# {'ETS': 0.06247489502981398, 'ARIMA': 0.06984833085009393, 'SARIMA': 0.08067731558675198}
# 48
# {'ETS': 0.019030020870429782, 'ARIMA': 0.021411667329688595, 'SARIMA': 0.021411667329688595}
# 49
# {'ETS': 0.08967095084038584, 'ARIMA': 0.12268157783492874, 'SARIMA': 0.12268157783492874}
# /opt/anaconda3/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 50
# {'ETS': 0.012338306841000056, 'ARIMA': 0.011605120926529135, 'SARIMA': 0.015185517394327767}
# 51
# {'ETS': 0.010756719321742882, 'ARIMA': 0.011900596696162965, 'SARIMA': 0.011900596696162965}
# 52
# {'ETS': 0.0883395746233066, 'ARIMA': 0.08053318565464156, 'SARIMA': 0.08053318565464156}
# 53
# {'ETS': 0.0612263271122326, 'ARIMA': 0.12273796465849128, 'SARIMA': 0.12273796465849128}
# 54
# {'ETS': 0.15321713933655498, 'ARIMA': 0.19056772058572444, 'SARIMA': 0.19056772058572444}
# 55
# {'ETS': 0.2249736334196012, 'ARIMA': 0.2672938256495085, 'SARIMA': 0.2674949611489675}
# 56
# {'ETS': 0.09355426636990509, 'ARIMA': 0.6184602182413752, 'SARIMA': 0.49858950268673485}
# 57
# {'ETS': 0.07311269983377683, 'ARIMA': 0.04475149203829653, 'SARIMA': 0.04475149203829653}
# 58
# {'ETS': 0.06163367386918999, 'ARIMA': 0.052804100190891136, 'SARIMA': 0.052804100190891136}
# 59
# {'ETS': 0.11699850663439253, 'ARIMA': 0.06737301418851735, 'SARIMA': 0.10000653184533843}
# 60
# {'ETS': 0.028818579321080656, 'ARIMA': 0.041682369660499735, 'SARIMA': 0.041682369660499735}
# 61
# {'ETS': 0.09753099005474415, 'ARIMA': 0.09837732666617262, 'SARIMA': 0.09837732666617262}
# 62
# {'ETS': 0.2967718582850844, 'ARIMA': 0.277291254083053, 'SARIMA': 0.277291254083053}
# 63
# {'ETS': 0.07145039111682462, 'ARIMA': 0.07458908314596281, 'SARIMA': 0.07458908314596281}
# 64
# {'ETS': 0.04459547517321246, 'ARIMA': 0.037934722677178394, 'SARIMA': 0.037934722677178394}
# 65
# {'ETS': 0.1837609276474321, 'ARIMA': 0.13494841078389494, 'SARIMA': 0.08915754105537209}
# 66
# {'ETS': 0.06982197195742142, 'ARIMA': 0.053330834438951445, 'SARIMA': 0.07122534747986507}
# 67
# {'ETS': 0.10453351748127092, 'ARIMA': 0.10049031024200278, 'SARIMA': 0.09277660683339957}
# 68
# {'ETS': 0.12452314243741285, 'ARIMA': 0.13759168928715534, 'SARIMA': 0.1350736162279481}
# 69
# {'ETS': 0.035088591256015135, 'ARIMA': 0.02786124097451702, 'SARIMA': 0.02786124097451702}
# 70
# {'ETS': 0.15213015456501197, 'ARIMA': 0.1600780286590152, 'SARIMA': 0.1600780286590152}

# %%
metrics_df = pd.DataFrame(results)

# Агрегаты
stats = pd.DataFrame({
    'mean': metrics_df.mean(),
    'median': metrics_df.median(),
    'max': metrics_df.max()
})

stats = 100 * stats
stats.columns.name = 'Model'
stats.index.name = 'Aggregate'
stats = stats.round(2)
stats
# Out:
# Model       mean  median    max
# Aggregate
# ETS        11.99    9.53  43.71
# ARIMA      12.86    9.94  61.85
# SARIMA     12.79   10.15  49.86

# %%
metrics_df.mean()
# Out:
# Aggregate
# ETS       0.119872
# ARIMA     0.128623
# SARIMA    0.127922
# dtype: float64

# %%
num = 15

test_start = '2024-01'
test_end = '2024-12'

series = df.iloc[:, num].dropna()
train = series[series.index < test_start]
test = series[(series.index >= test_start) & (series.index <= test_end)]

forecaster = AutoETS(auto=True, sp=12, n_jobs=-1)  # sp=12 для месячных данных
forecaster.fit(train)
fh = ForecastingHorizon(test.index, is_relative=False)
y_pred = forecaster.predict(fh)


plt.figure(figsize=(10, 5))
plt.plot(test.index.to_timestamp(), test.values, 'o-', color='blue', label="Тест (2024)")
plt.plot(y_pred.index.to_timestamp(), y_pred.values, 'o-', color='red', label="Прогноз (AutoETS)")
plt.title("Прогноз AutoETS vs Реальные значения (2024)")
plt.xlabel("Месяц")
plt.ylabel(df.columns[num])
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()


mape = mean_absolute_percentage_error(test, y_pred)
print(f"MAPE (2024): {mape:.4f} ({mape*100:.2f}%)")
# Out:
# MAPE (2024): 0.1362 (13.62%)

# %%
num = 20

test_start = '2024-01'
test_end = '2024-12'

series = df.iloc[:, num].dropna()
train = series[series.index < test_start]
test = series[(series.index >= test_start) & (series.index <= test_end)]

forecaster = AutoARIMA(
    sp=12,
    seasonal=True,
    stepwise=False,       
    n_jobs=-1,           
    trace=False,
    error_action='ignore', 
    suppress_warnings=True
)
forecaster.fit(train)
fh = ForecastingHorizon(test.index, is_relative=False)
y_pred = forecaster.predict(fh)


plt.figure(figsize=(10, 5))
plt.plot(test.index.to_timestamp(), test.values, 'o-', color='blue', label="Тест (2024)")
plt.plot(y_pred.index.to_timestamp(), y_pred.values, 'o-', color='red', label="Прогноз (AutoETS)")
plt.title("Прогноз AutoETS vs Реальные значения (2024)")
plt.xlabel("Месяц")
plt.ylabel(df.columns[num])
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

mape = mean_absolute_percentage_error(test, y_pred)
print(f"MAPE (2024): {mape:.4f} ({mape*100:.2f}%)")
# Out:
# MAPE (2024): 0.0896 (8.96%)

# %%
num = 15

test_start = '2024-01'
test_end = '2024-12'

series = df.iloc[:, num].dropna()
train = series[series.index < test_start]
test = series[(series.index >= test_start) & (series.index <= test_end)]

forecaster.fit(train)
fh = ForecastingHorizon(test.index, is_relative=False)
y_pred = forecaster.predict(fh)

plt.figure(figsize=(10, 5))
plt.plot(test.index.to_timestamp(), test.values, 'o-', color='blue', label="Тест (2024)")
plt.plot(y_pred.index.to_timestamp(), y_pred.values, 'o-', color='red', label="Прогноз (AutoETS)")
plt.title("Прогноз AutoETS vs Реальные значения (2024)")
plt.xlabel("Месяц")
plt.ylabel(df.columns[num])
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

mape = mean_absolute_percentage_error(test, y_pred)
print(f"MAPE (2024): {mape:.4f} ({mape*100:.2f}%)")
# Out:
# MAPE (2024): 0.1630 (16.30%)

# %%
num = 15

test_start = '2024-01'
test_end = '2024-12'

series = df.iloc[:, num].dropna()
train = series[series.index < test_start]
test = series[(series.index >= test_start) & (series.index <= test_end)]

forecaster = Prophet(
    seasonality_mode='multiplicative', 
    n_changepoints=int(len(train) / 12),  
    yearly_seasonality=True
)
forecaster.fit(train)
fh = ForecastingHorizon(test.index, is_relative=False)
y_pred = forecaster.predict(fh)


plt.figure(figsize=(10, 5))
plt.plot(test.index.to_timestamp(), test.values, 'o-', color='blue', label="Тест (2024)")
plt.plot(y_pred.index.to_timestamp(), y_pred.values, 'o-', color='red', label="Прогноз (AutoETS)")
plt.title("Прогноз AutoETS vs Реальные значения (2024)")
plt.xlabel("Месяц")
plt.ylabel(df.columns[num])
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()


mape = mean_absolute_percentage_error(test, y_pred)
print(f"MAPE (2024): {mape:.4f} ({mape*100:.2f}%)")
# Out:
# 07:37:08 - cmdstanpy - INFO - Chain [1] start processing
# 07:37:08 - cmdstanpy - INFO - Chain [1] done processing
# MAPE (2024): 0.1671 (16.71%)
